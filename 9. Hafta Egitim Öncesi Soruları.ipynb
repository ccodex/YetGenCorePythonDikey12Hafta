# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
# 1.Problemin Çözümünü Buraya Yazınız
class Vehicle():
    def __init__(self, tür, yas, kapasite, sınıf):
        self.tür = tür
        self.kapasite = kapasite
        self.yas = yas
        self.sınıf = sınıf

bus = Vehicle("otobüs" , "50" , "12" "A")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       6         self.yas = yas
#       7         self.sınıf = sınıf
# ----> 9 bus = Vehicle("otobüs" , "50" , "12" "A")
#
# TypeError: Vehicle.__init__() missing 1 required positional argument: 'sınıf'

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
class Vehicle():
    def __init__(self, tür, yas, kapasite, sınıf):
        self.tür = tür
        self.kapasite = kapasite
        self.yas = yas
        self.sınıf = sınıf



class ShcoolBus():
    def __init__(self, yas, kapasite, sınıf):
        self.kapasite = kapasite
        self.yas = yas
        self.sınıf = sınıf
